# %%
import pandas as pd
import matplotlib.pyplot as plt

table_booking_percentage = (df["Has Table booking"] == "Yes").mean() * 100
online_delivery_percentage = (df["Has Online delivery"] == "Yes").mean() * 100

print("Percentage of Restaurants with Table Booking: {:.2f}%".format(table_booking_percentage))
print("Percentage of Restaurants with Online Delivery: {:.2f}%".format(online_delivery_percentage))

avg_rating_table = df.groupby("Has Table booking")["Aggregate rating"].mean()

print("\nAverage Ratings Based on Table Booking:")
print(avg_rating_table)

plt.figure(figsize=(6,4))
avg_rating_table.plot(kind="bar")
plt.title("Average Rating: Table Booking vs No Table Booking")
plt.xlabel("Has Table Booking")
plt.ylabel("Average Rating")
plt.xticks(rotation=0)
plt.show()

online_delivery_price = pd.crosstab(df["Price range"], df["Has Online delivery"])

print("\nOnline Delivery by Price Range:")
print(online_delivery_price)

online_delivery_price.plot(kind="bar", figsize=(8,5))
plt.title("Online Delivery Availability by Price Range")
plt.xlabel("Price Range")
plt.ylabel("Number of Restaurants")
plt.xticks(rotation=0)
plt.show()
# Out:
# Percentage of Restaurants with Table Booking: 12.12%
# Percentage of Restaurants with Online Delivery: 25.66%
#
# Average Ratings Based on Table Booking:
# Has Table booking
# No     2.559359
# Yes    3.441969
# Name: Aggregate rating, dtype: float64
# Online Delivery by Price Range:
# Has Online delivery    No   Yes
# Price range
# 1                    3743   701
# 2                    1827  1286
# 3                     997   411
# 4                     533    53

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print(f'User uploaded file "{fn}" with length {len(uploaded[fn])} bytes')
# Out:
#      <input type="file" id="files-7c1cb230-3a79-4ae8-bbcf-c5058d5f9a2c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7c1cb230-3a79-4ae8-bbcf-c5058d5f9a2c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# After uploading the file, you can re-run the previous cell (cell EHU-CvxSnVUe) to load the `Dataset.csv` into a pandas DataFrame and continue with your analysis.

# %%
import pandas as pd
import matplotlib.pyplot as plt

print("Most Common Price Range:")
print(df["Price range"].value_counts())

most_common = df["Price range"].mode()[0]
print(f"\nMost Common Price Range: {most_common}")

plt.figure(figsize=(6,4))
df["Price range"].value_counts().sort_index().plot(kind="bar")
plt.title("Distribution of Price Range")
plt.xlabel("Price Range")
plt.ylabel("Number of Restaurants")
plt.xticks(rotation=0)
plt.show()

avg_rating = df.groupby("Price range")["Aggregate rating"].mean()

print("\nAverage Rating by Price Range:")
print(avg_rating)

plt.figure(figsize=(6,4))
avg_rating.plot(kind="bar")
plt.title("Average Rating by Price Range")
plt.xlabel("Price Range")
plt.ylabel("Average Rating")
plt.xticks(rotation=0)
plt.show()

color_rating = df.groupby("Rating color")["Aggregate rating"].mean().sort_values(ascending=False)

print("\nAverage Rating by Rating Color:")
print(color_rating)

highest_color = color_rating.idxmax()
highest_rating = color_rating.max()

print(f"\nRating Color with Highest Average Rating: {highest_color}")
print(f"Highest Average Rating: {highest_rating:.2f}")

plt.figure(figsize=(8,4))
color_rating.plot(kind="bar")
plt.title("Average Rating by Rating Color")
plt.xlabel("Rating Color")
plt.ylabel("Average Rating")
plt.xticks(rotation=0)
plt.show()
# Out:
# Most Common Price Range:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: count, dtype: int64
#
# Most Common Price Range: 1
# Average Rating by Price Range:
# Price range
# 1    1.999887
# 2    2.941054
# 3    3.683381
# 4    3.817918
# Name: Aggregate rating, dtype: float64
# Average Rating by Rating Color:
# Rating color
# Dark Green    4.659801
# Green         4.168119
# Yellow        3.683429
# Orange        3.051619
# Red           2.297849
# White         0.000000
# Name: Aggregate rating, dtype: float64
#
# Rating Color with Highest Average Rating: Dark Green
# Highest Average Rating: 4.66

# %%
import pandas as pd

df["Restaurant Name Length"] = df["Restaurant Name"].str.len()

df["Address Length"] = df["Address"].str.len()

df["Table Booking"] = df["Has Table booking"].map({"Yes": 1, "No": 0})

df["Online Delivery"] = df["Has Online delivery"].map({"Yes": 1, "No": 0})

print("New Features Created Successfully!\n")

print(df[[
    "Restaurant Name",
    "Restaurant Name Length",
    "Address",
    "Address Length",
    "Has Table booking",
    "Table Booking",
    "Has Online delivery",
    "Online Delivery"
]].head(10))

df.to_csv("Feature_Engineering_Output.csv", index=False)

print("\nFeature Engineering Completed Successfully!")
print("Updated dataset saved as 'Feature_Engineering_Output.csv'")
# Out:
# New Features Created Successfully!
#
#                             Restaurant Name  Restaurant Name Length  \
# 0                          Le Petit Souffle                      16
# 1                          Izakaya Kikufuji                      16
# 2                    Heat - Edsa Shangri-La                      22
# 3                                      Ooma                       4
# 4                               Sambo Kojin                      11
# 5                              Din Tai Fung                      12
# 6                                Buffet 101                      10
# 7                                   Vikings                       7
# 8  Spiral - Sofitel Philippine Plaza Manila                      40
# 9                                  Locavore                       8
#
#                                              Address  Address Length  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...              71
# ...
